# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/dineshchandgeetharavichandran/Library/Python/3.10/lib/python/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.19.3 in /Users/dineshchandgeetharavichandran/Library/Python/3.10/lib/python/site-packages (from opencv-python) (2.0.2)
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Python code to read image
import cv2

# To read image from disk, we use
# cv2.imread function, in below method,
img = cv2.imread("img1.png", cv2.IMREAD_COLOR)

# Creating GUI window to display an image on screen
# first Parameter is windows title (should be in string format)
# Second Parameter is image array
cv2.imshow("image", img)

# To hold the window on screen, we use cv2.waitKey method
# Once it detected the close input, it will release the control
# To the next line
# First Parameter is for holding screen for specified milliseconds
# It should be positive integer. If 0 pass an parameter, then it will
# hold the screen until user close it.
cv2.waitKey(0)

# It is for removing/deleting created GUI window from screen
# and memory
cv2.destroyAllWindows()
# Out:
# 2025-01-07 15:10:23.571 Python[50861:6034461] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %%
import cv2
import numpy as np
import matplotlib
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
img=cv2.imread("img1.png")
#Displaying image using plt.imshow() method
plt.imshow(img)

#hold the window
plt.waitforbuttonpress()
plt.close('all')
# Out:
# /var/folders/8_/wfp348kn2dq3bn994w75sqrm0000gp/T/ipykernel_60544/17763601.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.waitforbuttonpress()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       8 plt.imshow(img)
#      10 #hold the window
# ---> 11 plt.waitforbuttonpress()
#      12 plt.close('all')
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/pyplot.py:2841, in waitforbuttonpress(timeout)
#    2839 @_copy_docstring_and_deprecators(Figure.waitforbuttonpress)
#    2840 def waitforbuttonpress(timeout: float = -1) -> None | bool:
# -> 2841     return gcf().waitforbuttonpress(timeout=timeout)
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/figure.py:3603, in Figure.waitforbuttonpress(self, timeout)
#    3600     event = ev
#    3601     self.canvas.stop_event_loop()
# -> 3603 _blocking_input.blocking_input_loop(
#    3604     self, ["button_press_event", "key_press_event"], timeout, handler)
#    3606 return None if event is None else event.name == "key_press_event"
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/_blocking_input.py:26, in blocking_input_loop(figure, event_names, timeout, handler)
#      24 cids = [figure.canvas.mpl_connect(name, handler) for name in event_names]
#      25 try:
# ---> 26     figure.canvas.start_event_loop(timeout)  # Start event loop.
#      27 finally:  # Run even on exception like ctrl-c.
#      28     # Disconnect the callbacks.
#      29     for cid in cids:
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/backend_bases.py:2365, in FigureCanvasBase.start_event_loop(self, timeout)
#    2363 while self._looping and counter * timestep < timeout:
#    2364     self.flush_events()
# -> 2365     time.sleep(timestep)
#    2366     counter += 1
#
# KeyboardInterrupt:

# %%
#import cv2, numpy and matplotlib libraries
import cv2
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
img=cv2.imread("img1.png")

# Converting BGR color to RGB color format
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Displaying image using plt.imshow() method
plt.imshow(RGB_img)

# hold the window
plt.waitforbuttonpress()
plt.close('all')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 import numpy as np
#       4 import matplotlib
# ----> 5 matplotlib.use('TkAgg')
#       6 import matplotlib.pyplot as plt
#       7 img=cv2.imread("img1.png")
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/__init__.py:1281, in use(backend, force)
#    1276 if plt is not None:
#    1277     try:
#    1278         # we need this import check here to re-raise if the
#    1279         # user does not have the libraries to support their
#    1280         # chosen backend installed.
# -> 1281         plt.switch_backend(name)
#    1282     except ImportError:
#    1283         if force:
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/pyplot.py:425, in switch_backend(newbackend)
#     422         return
#     423 old_backend = rcParams._get('backend')  # get without triggering backend resolution
# --> 425 module = backend_registry.load_backend_module(newbackend)
#     426 canvas_class = module.FigureCanvas
#     428 required_framework = canvas_class.required_interactive_framework
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/backends/registry.py:317, in BackendRegistry.load_backend_module(self, backend)
#     303 """
#     304 Load and return the module containing the specified backend.
#     305
#    (...)
#     314     Module containing backend.
#     315 """
#     316 module_name = self._backend_module_name(backend)
# --> 317 return importlib.import_module(module_name)
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/backends/backend_tkagg.py:1
# ----> 1 from . import _backend_tk
#       2 from .backend_agg import FigureCanvasAgg
#       3 from ._backend_tk import _BackendTk, FigureCanvasTk
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib/backends/_backend_tk.py:9
#       7 import pathlib
#       8 import sys
# ----> 9 import tkinter as tk
#      10 import tkinter.filedialog
#      11 import tkinter.font
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/tkinter/__init__.py:37
#      34 import sys
#      35 import types
# ---> 37 import _tkinter # If this fails your Python may not be configured for Tk
#      38 TclError = _tkinter.TclError
#      39 from tkinter.constants import *
#
# ModuleNotFoundError: No module named '_tkinter'

# %% [markdown]
# Opening in Grayscale

# %%
# Python program to explain cv2.imread() method 

# importing cv2 
import cv2 
# path 
path = r'img1.png'

# Using cv2.imread() method 
# Using 0 to read image in grayscale mode 
img = cv2.imread(path, cv2.IMREAD_GRAYSCALE) 

# Displaying the image 
cv2.imshow('image', img) 

# Add a loop to handle GUI events
while True:
    key = cv2.waitKey(1) & 0xFF  # Wait for 1 ms
    if key == ord('q') or cv2.getWindowProperty('image', cv2.WND_PROP_VISIBLE) < 1:
        break

# Destroy all OpenCV windows
cv2.destroyAllWindows()
# Out:
# 2025-01-07 19:21:48.577 Python[60544:6122859] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %%
import cv2

# Specify the path to your image
image_path = 'img1.png'

# Load the image
image = cv2.imread(image_path)

# Check if image was loaded properly
if image is not None:
    cv2.imshow('Loaded Image', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Error loading the image")
# Out:
# 2025-01-07 15:56:34.290 Python[54740:6060306] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %%
import cv2

# Read an image
image = cv2.imread('img1.png')

# Save the image
cv2.imwrite('img2.jpg', image)
# Out:
# True

# %% [markdown]
# Colour Saturation

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 4.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dineshchandgeetharavichandran/Library/Python/3.10/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 2.8 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp310-cp310-macosx_11_0_arm64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/dineshchandgeetharavichandran/Library/Python/3.10/lib/python/site-packages (from matplotlib) (24.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.3/253.3 kB 5.1 MB/s eta 0:00:00a 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 8.1 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.3-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.23 in /Users/dineshchandgeetharavichandran/Library/Python/3.10/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: six>=1.5 in /Users/dineshchandgeetharavichandran/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 
import matplotlib
import matplotlib.pyplot as plt

image = cv2.imread('rgb_paint.png') 
B, G, R = cv2.split(image) 
# Corresponding channels are separated 

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")

# Display the blue channel
plt.subplot(2, 2, 2)
plt.imshow(B, cmap="gray")
plt.title("Blue Channel")
plt.axis("off")

# Display the green channel
plt.subplot(2, 2, 3)
plt.imshow(G, cmap="gray")
plt.title("Green Channel")
plt.axis("off")

# Display the red channel
plt.subplot(2, 2, 4)
plt.imshow(R, cmap="gray")
plt.title("Red Channel")
plt.axis("off")

plt.show()
